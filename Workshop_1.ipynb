# %% [markdown]
# # **Introduction to Python Imaging Library(PIL)**
#
# 2.1 Exercise - 1:
# Complete all the Task.
#
# 1. Read and display the image.
#
# • Read the image using the Pillow library and display it.
#
# • You can also use matplotlib to display the image.

# %%
from PIL import Image

# %%
image_colored = Image.open("/content/drive/MyDrive/Colab Notebooks/AI and Machine Learning/Week-1/lenna_image.png")
display(image_colored)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=366x357>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
import numpy as np
import matplotlib.pyplot as plt

image_array_colored = np.array(image_colored)
image_array_colored.shape
top_left_corner = image_array_colored[:100, :100]
plt.imshow(top_left_corner)
plt.show()

# Crop using PIL
left = 100
upper = 50
right = 200
lower = 150
cropped_image = image_colored.crop((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %% [markdown]
# Show the three color channels (R, G, B).
#
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
image_colored = image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %%
#Extracting red channel
red_channel =image_array_colored.copy()
red_channel[:,:,1] = 0 #[row, column , sabai 1st index lai = 0 garko cha i.e Green(g) ko value]
red_channel[:,:,2] = 0 #[row, column , sabai 2nd index lai = 0 garko cha i.e Blue(b) ko value]
print(red_channel)
display(red_channel)
# Out:
# [[[225   0   0 255]
#   [224   0   0 255]
#   [226   0   0 255]
#   ...
#   [ 92   0   0 255]
#   [ 90   0   0 255]
#   [ 91   0   0 255]]
#
#  [[225   0   0 255]
#   [224   0   0 255]
#   [224   0   0 255]
#   ...
#   [ 91   0   0 255]
#   [ 90   0   0 255]
#   [ 91   0   0 255]]
#
#  [[223   0   0 255]
#   [223   0   0 255]
#   [224   0   0 255]
#   ...
#   [ 93   0   0 255]
#   [ 91   0   0 255]
#   [ 91   0   0 255]]
#
#  ...
#
#  [[ 88   0   0 255]
#   [ 92   0   0 255]
#   [ 95   0   0 255]
#   ...
#   [148   0   0 255]
#   [162   0   0 255]
#   [175   0   0 255]]
#
#  [[ 88   0   0 255]
#   [ 92   0   0 255]
#   [ 96   0   0 255]
#   ...
#   [154   0   0 255]
#   [168   0   0 255]
#   [177   0   0 255]]
#
#  [[254   0   0 255]
#   [254   0   0 255]
#   [254   0   0 255]
#   ...
#   [255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]]]
# array([[[225,   0,   0, 255],
#         [224,   0,   0, 255],
#         [226,   0,   0, 255],
#         ...,
#         [ 92,   0,   0, 255],
#         [ 90,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        [[225,   0,   0, 255],
#         [224,   0,   0, 255],
#         [224,   0,   0, 255],
#         ...,
#         [ 91,   0,   0, 255],
#         [ 90,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        [[223,   0,   0, 255],
#         [223,   0,   0, 255],
#         [224,   0,   0, 255],
#         ...,
#         [ 93,   0,   0, 255],
#         [ 91,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        ...,
#
#        [[ 88,   0,   0, 255],
#         [ 92,   0,   0, 255],
#         [ 95,   0,   0, 255],
#         ...,
#         [148,   0,   0, 255],
#         [162,   0,   0, 255],
#         [175,   0,   0, 255]],
#
#        [[ 88,   0,   0, 255],
#         [ 92,   0,   0, 255],
#         [ 96,   0,   0, 255],
#         ...,
#         [154,   0,   0, 255],
#         [168,   0,   0, 255],
#         [177,   0,   0, 255]],
#
#        [[254,   0,   0, 255],
#         [254,   0,   0, 255],
#         [254,   0,   0, 255],
#         ...,
#         [255,   0,   0, 255],
#         [255,   0,   0, 255],
#         [255,   0,   0, 255]]], dtype=uint8)

# %%
#Extracting blue channel
blue_channel =image_array_colored.copy()
blue_channel[:,:,1] = 0
blue_channel[:,:,0] = 0
print(blue_channel)
display(blue_channel)
# Out:
# [[[  0   0 110 255]
#   [  0   0 106 255]
#   [  0   0 105 255]
#   ...
#   [  0   0  64 255]
#   [  0   0  62 255]
#   [  0   0  56 255]]
#
#  [[  0   0 110 255]
#   [  0   0 104 255]
#   [  0   0 114 255]
#   ...
#   [  0   0  64 255]
#   [  0   0  61 255]
#   [  0   0  63 255]]
#
#  [[  0   0 105 255]
#   [  0   0 114 255]
#   [  0   0 111 255]
#   ...
#   [  0   0  67 255]
#   [  0   0  65 255]
#   [  0   0  61 255]]
#
#  ...
#
#  [[  0   0  58 255]
#   [  0   0  58 255]
#   [  0   0  60 255]
#   ...
#   [  0   0  78 255]
#   [  0   0  84 255]
#   [  0   0  78 255]]
#
#  [[  0   0  58 255]
#   [  0   0  61 255]
#   [  0   0  61 255]
#   ...
#   [  0   0  83 255]
#   [  0   0  85 255]
#   [  0   0  77 255]]
#
#  [[  0   0 254 255]
#   [  0   0 254 255]
#   [  0   0 254 255]
#   ...
#   [  0   0 255 255]
#   [  0   0 255 255]
#   [  0   0 255 255]]]
# array([[[  0,   0, 110, 255],
#         [  0,   0, 106, 255],
#         [  0,   0, 105, 255],
#         ...,
#         [  0,   0,  64, 255],
#         [  0,   0,  62, 255],
#         [  0,   0,  56, 255]],
#
#        [[  0,   0, 110, 255],
#         [  0,   0, 104, 255],
#         [  0,   0, 114, 255],
#         ...,
#         [  0,   0,  64, 255],
#         [  0,   0,  61, 255],
#         [  0,   0,  63, 255]],
#
#        [[  0,   0, 105, 255],
#         [  0,   0, 114, 255],
#         [  0,   0, 111, 255],
#         ...,
#         [  0,   0,  67, 255],
#         [  0,   0,  65, 255],
#         [  0,   0,  61, 255]],
#
#        ...,
#
#        [[  0,   0,  58, 255],
#         [  0,   0,  58, 255],
#         [  0,   0,  60, 255],
#         ...,
#         [  0,   0,  78, 255],
#         [  0,   0,  84, 255],
#         [  0,   0,  78, 255]],
#
#        [[  0,   0,  58, 255],
#         [  0,   0,  61, 255],
#         [  0,   0,  61, 255],
#         ...,
#         [  0,   0,  83, 255],
#         [  0,   0,  85, 255],
#         [  0,   0,  77, 255]],
#
#        [[  0,   0, 254, 255],
#         [  0,   0, 254, 255],
#         [  0,   0, 254, 255],
#         ...,
#         [  0,   0, 255, 255],
#         [  0,   0, 255, 255],
#         [  0,   0, 255, 255]]], dtype=uint8)

# %%
#Extracting green channel
green_channel =image_array_colored.copy()
green_channel[:,:,0] = 0
green_channel[:,:,2] = 0
print(green_channel)
plt.imshow(green_channel)
# Out:
# [[[  0 127   0 255]
#   [  0 130   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  23   0 255]
#   [  0  17   0 255]]
#
#  [[  0 130   0 255]
#   [  0 128   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  22   0 255]
#   [  0  22   0 255]
#   [  0  20   0 255]]
#
#  [[  0 128   0 255]
#   [  0 133   0 255]
#   [  0 129   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  22   0 255]
#   [  0  17   0 255]]
#
#  ...
#
#  [[  0  23   0 255]
#   [  0  22   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  57   0 255]
#   [  0  68   0 255]
#   [  0  66   0 255]]
#
#  [[  0  26   0 255]
#   [  0  27   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  63   0 255]
#   [  0  71   0 255]
#   [  0  66   0 255]]
#
#  [[  0 254   0 255]
#   [  0 254   0 255]
#   [  0 254   0 255]
#   ...
#   [  0 255   0 255]
#   [  0 255   0 255]
#   [  0 255   0 255]]]

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
#
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
image_modified = image_array_colored.copy()
image_modified[:100, :100] = 210
plt.imshow(image_modified)

# %% [markdown]
# # **Exercise - 2:**
#
# Complete all the Task.
# 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.
# • Display the grayscale image using matplotlib.

# %%
image_grayed = image_colored.convert('L')
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
#
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
# • Display this cropped image using matplotlib.

# %%
import numpy as np
image_array_grayscale = np.array(image_grayed)

height, width = image_array_grayscale.shape  # Only two values since it's grayscale
crop_size = 150

left = width // 2 - crop_size // 2 #width // 2 and height // 2 give the center coordinates of image.
upper = height // 2 - crop_size // 2
right = width // 2 + crop_size // 2
lower = height // 2 + crop_size // 2

center_cropped_image = image_array_grayscale[upper:lower, left:right]
display(center_cropped_image)
# Out:
# array([[ 89, 103, 112, ..., 189, 191, 192],
#        [104, 106, 104, ..., 191, 192, 195],
#        [107, 108, 109, ..., 191, 196, 195],
#        ...,
#        [137, 121, 151, ...,  77,  89,  88],
#        [132, 120, 169, ...,  73,  87,  98],
#        [123, 112, 167, ...,  74,  89,  91]], dtype=uint8)

# %% [markdown]
# Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
#
# • Display the resulting binary image.

# %%
threshold = 100
binary_image = np.where(image_array_grayscale < threshold, 0, 255)
plt.imshow(binary_image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
#
# • Display the rotated image using matplotlib.

# %%
rotated_image_pillow = image_colored.rotate(-90)
display(rotated_image_pillow)
# Out:
# <PIL.Image.Image image mode=RGB size=366x357>

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
#
# • Display the converted RGB image using matplotlib.

# %%
image_rgb_array = np.stack((image_array_grayscale ,) * 3, axis=-1)
display(image_rgb_array)
# Out:
# array([[[154, 154, 154],
#         [155, 155, 155],
#         [156, 156, 156],
#         ...,
#         [ 49,  49,  49],
#         [ 47,  47,  47],
#         [ 44,  44,  44]],
#
#        [[156, 156, 156],
#         [154, 154, 154],
#         [156, 156, 156],
#         ...,
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         [ 46,  46,  46]],
#
#        [[154, 154, 154],
#         [158, 158, 158],
#         [155, 155, 155],
#         ...,
#         [ 50,  50,  50],
#         [ 48,  48,  48],
#         [ 44,  44,  44]],
#
#        ...,
#
#        [[ 46,  46,  46],
#         [ 47,  47,  47],
#         [ 51,  51,  51],
#         ...,
#         [ 87,  87,  87],
#         [ 98,  98,  98],
#         [100, 100, 100]],
#
#        [[ 48,  48,  48],
#         [ 50,  50,  50],
#         [ 51,  51,  51],
#         ...,
#         [ 92,  92,  92],
#         [102, 102, 102],
#         [100, 100, 100]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# Image Compression and Decompression using PCA.
#
# In this exercise, build a PCA from scratch using explained variance method for image compression task.
#
# You are expected to compute the necessary matrices from the scratch. Dataset: Use image of your
# choice.
#
# 1. Load and Prepare Data:
# • Fetch an image of you choice.{If colour convert to grayscale}
# • Center the dataset - Standaridze the Data.
# • Calculate the covaraince matrix of the Standaridze data.

# %%
image = Image.open("/content/drive/MyDrive/Colab Notebooks/AI and Machine Learning/Week-1/camera_man.jpg").convert("L")

image_array = np.array(image)
print(image_array.shape)

height , width = image_array.shape

#data = image_array.reshepe(height , width)
data = image_array.copy()

plt.imshow(image_array, cmap = 'gray')
plt.show()
# Out:
# (325, 220)

# %%
mean = np.mean(data, axis=0)
# subtrat mean to center the data
centered_data = data - mean

cov_matrix = np.cov(centered_data, rowvar=False)
cov_matrix.shape
# Out:
# (220, 220)

# %% [markdown]
# Eigen Decomposition and Identifying Principal Components:
#
# • Compute Eigen Values and Eigen Vectors.
#
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
#
# • Identify the Principal Components with the help of cumulative Sum plot.

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
cumulative_explained_variance = np.cumsum(explained_variance_ratio)
plt.plot(cumulative_explained_variance)
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %%
#with different k values
k_value = [5, 10, 35, 80]  #choosing k principal component
plt.figure(figsize=(12, 8))

for i, k in enumerate(k_value):
    components = eigenvectors[:, :k]
    compressed_data = np.dot(centered_data, components)
    decompressed_data = np.dot(compressed_data, components.T) + mean
    decompressed_data = np.clip(decompressed_data, 0, 255)

    plt.subplot(2, 3, i + 1)
    plt.imshow(compressed_data, cmap = "gray", aspect = "auto")
    plt.title(f"Compressed Image (k={k})")
    plt.axis("off")

    plt.subplot(2, 3, i + 1)
    plt.imshow(decompressed_data, cmap="gray")
    plt.title(f"Decompressed Image (k={k})")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
compressed_data = np.dot(centered_data , components)

# %%
decompressed_data = np.dot(compressed_data, components.T) + mean

# %%
plt.figure(figsize=(12,6))
#Original Image
plt.subplot(1,3,1)
plt.imshow(image_array, cmap="gray")
plt.title("Original Image")

#Compressed Image
plt.subplot(1,3,2)
plt.imshow(compressed_data, cmap="gray", aspect = "auto")
plt.title(f"Compressed Image (k={k})")
plt.axis("off")

#Decompressed Image
plt.subplot(1,3,3)
plt.imshow(decompressed_data, cmap="gray")
plt.title("Decompressed Image")
plt.axis("off")
plt.tight_layout()

plt.show()
